# %% [markdown]
# <a href="https://colab.research.google.com/github/Maxmuthee/Supervised-Machine-Learning/blob/main/ConcreteStrength_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
file_name = 'Concrete_Data.xls'
df = pd.read_excel(file_name)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
X = df.iloc[:, :-1]  # All columns except the last one
y = df.iloc[:, -1]   # Only the last column

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

LR = LinearRegression().fit(X_train, y_train)
print("Training Accuracy: ",LR.score(X_train, y_train))
print("Testing Accuracy: ", LR.score(X_test, y_test))
# Out:
# Training Accuracy:  0.6108229424520566
# Testing Accuracy:  0.62341446236332

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
X = df.iloc[:, :-1]  # All columns except the last one
y = df.iloc[:, -1]   # Only the last column

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

LR = Ridge(alpha = 0.001).fit(X_train, y_train)
print("Training Accuracy: ",LR.score(X_train, y_train))
print("Testing Accuracy: ", LR.score(X_test, y_test))
# Out:
# Training Accuracy:  0.6108229424520565
# Testing Accuracy:  0.6234144627587369

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
X = df.iloc[:, :-1]  # All columns except the last one
y = df.iloc[:, -1]   # Only the last column

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=66)

LR = Lasso(alpha = 0.05).fit(X_train, y_train)
print("Training Accuracy: ",LR.score(X_train, y_train))
print("Testing Accuracy: ", LR.score(X_test, y_test))
# Out:
# Training Accuracy:  0.6160154813655287
# Testing Accuracy:  0.6103746778788411
